# %% [markdown]
# <a href="https://colab.research.google.com/github/Henriquerezer/Dissertacao/blob/main/Gridsearch_modelos_de_Regress%C3%A3o.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importe as bibliotecas necessárias
import pandas as pd
from sklearn.preprocessing import MinMaxScaler, StandardScaler, RobustScaler
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.neural_network import MLPRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_percentage_error, mean_absolute_error
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor

# %%
# Carregue um arquivo Excel em um DataFrame

# pelo caminho do seu arquivo de dados
data = pd.read_excel('/content/Treino (2).xlsx')

# Remova caracteres indesejados da coluna 'TEMP'
data['TEMP'] = data['TEMP'].str.replace("?", "")

# Remova o símbolo de porcentagem da coluna 'HUMIDADE'
data['HUMIDADE'] = data['HUMIDADE'].str.replace("%", "")

# Remova linhas com valores ausentes (NaN)
data = data.dropna()

# Converta os valores na coluna 'TEMP' para o tipo de dado float
data['TEMP'] = data['TEMP'].astype(float)

# Converta os valores na coluna 'HUMIDADE' para o tipo de dado float
data['HUMIDADE'] = data['HUMIDADE'].astype(float)

# O DataFrame 'data' agora contém os dados limpos e as colunas 'TEMP' e 'HUMIDADE'
# prontos para serem usados em análises ou modelagem de dados.
# Out:
# <ipython-input-2-0444e8eba491>:7: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   data['TEMP'] = data['TEMP'].str.replace("?", "")

# %% [markdown]
# # testando sem remover features e sem normalização

# %%
X = data.drop('mg/dL', axis=1)
y = data['mg/dL']

# Dividir os dados em conjuntos de treinamento e teste
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)

# Definir os hiperparâmetros para cada modelo
svm_params = {
    'C': [0.1, 1, 10],
    'kernel': ['linear', 'rbf']
}

rf_params = {
    'n_estimators': [100, 200, 300],
    'max_depth': [None, 5, 10],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}


knn_params = {
    'n_neighbors': [3, 5, 7],
    'weights': ['uniform', 'distance']
}

gb_params = {
    'n_estimators': [100, 200, 300],
    'learning_rate': [0.01, 0.1, 1],
    'max_depth': [3, 5, 10]
}

# Definir os hiperparâmetros para os novos modelos
xgb_params = {
    'n_estimators': [100, 200, 300],
    'learning_rate': [0.01, 0.1, 1],
    'max_depth': [3, 5, 10]
}

lgbm_params = {
    'n_estimators': [100, 200, 300],
    'learning_rate': [0.01, 0.1, 1],
    'max_depth': [3, 5, 10]
}

# Definir a lista de modelos com seus respectivos hiperparâmetros
models = [
#    (SVR(), svm_params),
#   (RandomForestRegressor(), rf_params),
#    (KNeighborsRegressor(), knn_params),
   (GradientBoostingRegressor(), gb_params),
#    (XGBRegressor(), xgb_params),
#    (LGBMRegressor(), lgbm_params),
]

# Lista para armazenar os resultados
results = []

# Iterar sobre os modelos
for model, params in models:
    # Criar o objeto GridSearchCV
    grid_search = GridSearchCV(estimator=model, param_grid=params, cv=10, verbose=5,
                               return_train_score=True, scoring='neg_mean_squared_error')

    # Realizar o grid search com cross-validation
    grid_search.fit(X_train, y_train)

    # Obter o melhor modelo encontrado
    best_model = grid_search.best_estimator_

    # Fazer previsões com o melhor modelo
    y_pred = best_model.predict(X_test)

    # Calcular as métricas de erro
    rmse = mean_squared_error(y_test, y_pred, squared=False)
    r2 = r2_score(y_test, y_pred)
    mape = mean_absolute_percentage_error(y_test, y_pred)
    mae = mean_absolute_error(y_test, y_pred)

    # Armazenar os resultados
    results.append({'Model': model.__class__.__name__,
                    'Best Parameters': grid_search.best_params_,
                    'RMSE': rmse,
                    'R²': r2,
                    'MAPE': mape,
                    'MAE': mae})

# Imprimir os resultados
for result in results:
    print('Model:', result['Model'])
    print('Best Parameters:', result['Best Parameters'])
    print('RMSE:', result['RMSE'])
    print('R²:', result['R²'])
    print('MAPE:', result['MAPE'])
    print('MAE:', result['MAE'])
    print()
# Out:
# Fitting 10 folds for each of 27 candidates, totalling 270 fits
# [CV 1/10] END learning_rate=0.01, max_depth=3, n_estimators=100;, score=(train=-2990.328, test=-5988.401) total time=   0.9s
# [CV 2/10] END learning_rate=0.01, max_depth=3, n_estimators=100;, score=(train=-2907.709, test=-6828.622) total time=   0.9s
# [CV 3/10] END learning_rate=0.01, max_depth=3, n_estimators=100;, score=(train=-2886.097, test=-8263.735) total time=   1.2s
# [CV 4/10] END learning_rate=0.01, max_depth=3, n_estimators=100;, score=(train=-3046.659, test=-6359.843) total time=   1.3s
# [CV 5/10] END learning_rate=0.01, max_depth=3, n_estimators=100;, score=(train=-2884.213, test=-4468.000) total time=   1.1s
# [CV 6/10] END learning_rate=0.01, max_depth=3, n_estimators=100;, score=(train=-3117.309, test=-4527.855) total time=   0.9s
# [CV 7/10] END learning_rate=0.01, max_depth=3, n_estimators=100;, score=(train=-3133.625, test=-5387.796) total time=   0.9s
# [CV 8/10] END learning_rate=0.01, max_depth=3, n_estimators=100;, score=(train=-2959.051, test=-4602.003) total time=   0.9s
# [CV 9/10] END learning_rate=0.01, max_depth=3, n_estimators=100;, score=(train=-2983.293, test=-8648.066) total time=   0.9s
# [CV 10/10] END learning_rate=0.01, max_depth=3, n_estimators=100;, score=(train=-3046.007, test=-6973.517) total time=   0.9s
# [CV 1/10] END learning_rate=0.01, max_depth=3, n_estimators=200;, score=(train=-1377.565, test=-4500.701) total time=   1.7s
# [CV 2/10] END learning_rate=0.01, max_depth=3, n_estimators=200;, score=(train=-1265.976, test=-5526.590) total time=   1.8s
# [CV 3/10] END learning_rate=0.01, max_depth=3, n_estimators=200;, score=(train=-1133.382, test=-7893.696) total time=   1.9s
# [CV 4/10] END learning_rate=0.01, max_depth=3, n_estimators=200;, score=(train=-1478.993, test=-4945.759) total time=   2.6s
# [CV 5/10] END learning_rate=0.01, max_depth=3, n_estimators=200;, score=(train=-
params = {
    'n_estimators': [100, 200, 300],
    'learning_rate': [0.01, 0.1, 1],
    'max_depth': [3, 5, 10]
}

lasso_params = {
    'alpha': [0.1, 1, 10]
}

ridge_params = {
    'alpha': [0.1, 1, 10]
}

elasticnet_params = {
    'alpha': [0.1, 1, 10],
    'l1_ratio': [0.2, 0.5, 0.8]
}

# Definir a lista de modelos com seus respectivos hiperparâmetros
models = [
#    (SVR(), svm_params),
#    (RandomForestRegressor(), rf_params),
#    (KNeighborsRegressor(), knn_params),
    (GradientBoostingRegressor(), gb_params),
#    (XGBRegressor(), xgb_params),
#   (LGBMRegressor(), lgbm_params),
]

# Definir a lista de normalizações
scalers = [
    ('MinMaxScaler', MinMaxScaler()),
    ('StandardScaler', StandardScaler()),
    ('RobustScaler', RobustScaler())
]

# Lista para armazenar os resultados
results = []

# Iterar sobre as normalizações
for scaler_name, scaler in scalers:
    # Normalizar os dados
    X_train_scaled = scaler.fit_transform(X_train)
    X_test_scaled = scaler.transform(X_test)

    # Iterar sobre os modelos
    for model, params in models:
        # Criar o objeto GridSearchCV
        grid_search = GridSearchCV(estimator=model, param_grid=params, cv=10, verbose=5,
                                   return_train_score=True, scoring='neg_mean_squared_error')

        # Realizar o grid search com cross-validation
        grid_search.fit(X_train_scaled, y_train)

        # Obter o melhor modelo encontrado
        best_model = grid_search.best_estimator_

        # Fazer previsões com o melhor modelo
        y_pred = best_model.predict(X_test_scaled)

        # Calcular as métricas de erro
        rmse = mean_squared_error(y_test, y_pred, squared=False)
        r2 = r2_score(y_test, y_pred)
        mape = mean_absolute_percentage_error(y_test, y_pred)
        mae = mean_absolute_error(y_test, y_pred)

        # Armazenar os resultados
        results.append({'Model': model.__class__.__name__,
                        'Normalization': scaler_name,
                        'Best Parameters': grid_search.best_params_,
                        'RMSE': rmse,
                        'R²': r2,
                        'MAPE': mape,
                        'MAE': mae})

# Imprimir os resultados
for result in results:
    print('Model:', result['Model'])
    print('Normalization:', result['Normalization'])
    print('Best Parameters:', result['Best Parameters'])
    print('RMSE:', result['RMSE'])
    print('R²:', result['R²'])
    print('MAPE:', result['MAPE'])
    print('MAE:', result['MAE'])
    print()
# Out:
# Fitting 10 folds for each of 27 candidates, totalling 270 fits
# [CV 1/10] END learning_rate=0.01, max_depth=3, n_estimators=100;, score=(train=-2990.328, test=-5953.011) total time=   0.9s
# [CV 2/10] END learning_rate=0.01, max_depth=3, n_estimators=100;, score=(train=-2907.709, test=-6876.512) total time=   0.9s
# [CV 3/10] END learning_rate=0.01, max_depth=3, n_estimators=100;, score=(train=-2881.034, test=-8351.378) total time=   0.9s
# [CV 4/10] END learning_rate=0.01, max_depth=3, n_estimators=100;, score=(train=-3046.659, test=-6392.697) total time=   0.9s
# [CV 5/10] END learning_rate=0.01, max_depth=3, n_estimators=100;, score=(train=-2877.312, test=-4576.352) total time=   0.9s
# [CV 6/10] END learning_rate=0.01, max_depth=3, n_estimators=100;, score=(train=-3117.309, test=-4552.781) total time=   0.9s
# [CV 7/10] END learning_rate=0.01, max_depth=3, n_estimators=100;, score=(train=-3133.625, test=-5419.319) total time=   0.9s
# [CV 8/10] END learning_rate=0.01, max_depth=3, n_estimators=100;, score=(train=-2959.051, test=-4580.407) total time=   1.2s
# [CV 9/10] END learning_rate=0.01, max_depth=3, n_estimators=100;, score=(train=-2983.293, test=-8663.409) total time=   1.3s
# [CV 10/10] END learning_rate=0.01, max_depth=3, n_estimators=100;, score=(train=-3047.281, test=-6956.021) total time=   1.0s
# [CV 1/10] END learning_rate=0.01, max_depth=3, n_estimators=200;, score=(train=-1404.224, test=-4660.125) total time=   1.7s
# [CV 2/10] END learning_rate=0.01, max_depth=3, n_estimators=200;, score=(train=-1199.898, test=-5571.534) total time=   1.7s
# [CV 3/10] END learning_rate=0.01, max_depth=3, n_estimators=200;, score=(train=-1137.112, test=-7941.946) total time=   1.7s
# [CV 4/10] END learning_rate=0.01, max_depth=3, n_estimators=200;, score=(train=-1479.545, test=-5059.083) total time=   1.7s
# [CV 5/10] END learning_rate=0.01, max_depth=3, n_estimators=200;, score=(train=-1219.832, test=-3452.403) total time=   1.7s
# [CV 6/10] END learning_rate=0.01, max_depth=3, n_estimators=200;, score=(train=-1287.099, test=-3136.295) total time=   2.2s
# [CV 7/10] END learning_rate=0.01, max_depth=3, n_estimators=200;, score=(train=-1384.513, test=-3625.014) total time=   2.2s
# [CV 8/10] END learning_rate=0.01, max_depth=3, n_estimators=200;, score=(train=-1251.080, test=-2842.555) total time=   1.8s
# [CV 9/10] END learning_rate=0.01, max_depth=3, n_estimators=200;, score=(train=-1112.734, test=-9327.322) total time=   1.7s
# [CV 10/10] END learning_rate=0.01, max_depth=3, n_estimators=200;, score=(train=-1341.325, test=-5684.763) total time=   1.7s
# [CV 1/10] END learning_rate=0.01, max_depth=3, n_estimators=300;, score=(train=-733.468, test=-3980.496) total time=   2.6s
# [CV 2/10] END learning_rate=0.01, max_depth=3, n_estimators=300;, score=(train=-637.833, test=-4928.820) total time=   3.2s
# [CV 3/10] END learning_rate=0.01, max_depth=3, n_estimators=300;, score=(train=-540.262, test=-7690.722) total time=   2.9s
# [CV 4/10] END learning_rate=0.01, max_depth=3, n_estimators=300;, score=(train=-818.116, test=-4467.764) total time=   2.6s
# [CV 5/10] END learning_rate=0.01, max_depth=3, n_estimators=300;, score=(train=-623.511, test=-2925.422) total time=   2.6s
# [CV 6/10] END learning_rate=0.01, max_depth=3, n_estimators=300;, score=(train=-631.981, test=-3064.813) total time=   2.6s
# [CV 7/10] END learning_rate=0.01, max_depth=3, n_estimators=300;, score=(train=-774.871, test=-3084.881) total time=   3.5s
# [CV 8/10] END learning_rate=0.01, max_depth=3, n_estimators=300;, score=(train=-642.910, test=-2296.499) total time=   2.6s
# [CV 9/10] END learning_rate=0.01, max_depth=3, n_estimators=300;, score=(train=-459.907, test=-9343.752) total time=   2.6s
# [CV 10/10] END learning_rate=0.01, max_depth=3, n_estimators=300;, score=(train=-707.706, test=-4849.080) total time=   2.6s
# [CV 1/10] END learning_rate=0.01, max_depth=5, n_estimators=100;, score=(train=-1546.249, test=-4881.977) total time=   1.3s
# [CV 2/10] END learning_rate=0.01, max_depth=5, n_estimators=100;, score=(train=-1927.365, test=-7330.345) total time=   1.8s
# [CV 3/10] END learning_rate=0.01, max_depth=5, n_estimators=100;, score=(train=-
10] END learning_rate=1, max_depth=3, n_estimators=300;, score=(train=-0.000, test=-13401.892) total time=   1.0s
# [CV 3/10] END learning_rate=1, max_depth=3, n_estimators=300;, score=(train=-0.000, test=-16872.786) total time=   1.0s
# [CV 4/10] END learning_rate=1, max_depth=3, n_estimators=300;, score=(train=-0.000, test=-3004.249) total time=   1.0s
# [CV 5/10] END learning_rate=1, max_depth=3, n_estimators=300;, score=(train=-0.000, test=-6479.401) total time=   1.0s
# [CV 6/10] END learning_rate=1, max_depth=3, n_estimators=300;, score=(train=-0.000, test=-3579.765) total time=   1.0s
# [CV 7/10] END learning_rate=1, max_depth=3, n_estimators=300;, score=(train=-0.000, test=-4103.948) total time=   1.4s
# [CV 8/10] END learning_rate=1, max_depth=3, n_estimators=300;, score=(train=-0.000, test=-2954.469) total time=   1.2s
# [CV 9/10] END learning_rate=1, max_depth=3, n_estimators=300;, score=(train=-0.000, test=-8482.441) total time=   1.0s
# [CV 10/10] END learning_rate=1, max_depth=3, n_estimators=300;, score=(train=-0.000, test=-9532.430) total time=   1.0s
# [CV 1/10] END learning_rate=1, max_depth=5, n_estimators=100;, score=(train=-0.000, test=-5554.223) total time=   0.7s
# [CV 2/10] END learning_rate=1, max_depth=5, n_estimators=100;, score=(train=-0.000, test=-6109.924) total time=   0.6s
# [CV 3/10] END learning_rate=1, max_depth=5, n_estimators=100;, score=(train=-0.000, test=-19214.105) total time=   0.6s
# [CV 4/10] END learning_rate=1, max_depth=5, n_estimators=100;, score=(train=-0.000, test=-8208.183) total time=   0.6s
# [CV 5/10] END learning_rate=1, max_depth=5, n_estimators=100;, score=(train=-0.000, test=-5511.266) total time=   0.6s
# [CV 6/10] END learning_rate=1, max_depth=5, n_estimators=100;, score=(train=-0.000, test=-1969.112) total time=   0.6s
# [CV 7/10] END learning_rate=1, max_depth=5, n_estimators=100;, score=(train=-0.000, test=-5725.577) total time=   0.6s
# [CV 8/10] END learning_rate=1, max_depth=5, n_estimators=100;, score=(train=-0.000, test=-4217.981) total time=   0.6s
# [CV 9/10] END learning_rate=1, max_depth=5, n_estimators=100;, score=(train=-0.000, test=-11757.367) total time=   0.6s
# [CV 10/10] END learning_rate=1, max_depth=5, n_estimators=100;, score=(train=-0.000, test=-11944.884) total time=   0.6s
# [CV 1/10] END learning_rate=1, max_depth=5, n_estimators=200;, score=(train=-0.000, test=-5389.622) total time=   0.7s
# [CV 2/10] END learning_rate=1, max_depth=5, n_estimators=200;, score=(train=-0.000, test=-6437.109) total time=   0.8s
# [CV 3/10] END learning_rate=1, max_depth=5, n_estimators=200;, score=(train=-0.000, test=-9506.865) total time=   0.9s
# [CV 4/10] END learning_rate=1, max_depth=5, n_estimators=200;, score=(train=-0.000, test=-5013.432) total time=   0.8s
# [CV 5/10] END learning_rate=1, max_depth=5, n_estimators=200;, score=(train=-0.000, test=-1858.125) total time=   0.7s
# [CV 6/10] END learning_rate=1, max_depth=5, n_estimators=200;, score=(train=-0.000, test=-3561.100) total time=   0.6s
# [CV 7/10] END learning_rate=1, max_depth=5, n_estimators=200;, score=(train=-0.000, test=-6656.972) total time=   0.7s
# [CV 8/10] END learning_rate=1, max_depth=5, n_estimators=200;, score=(train=-0.000, test=-3842.396) total time=   0.6s
# [CV 9/10] END learning_rate=1, max_depth=5, n_estimators=200;, score=(train=-0.000, test=-12383.460) total time=   0.7s
# [CV 10/10] END learning_rate=1, max_depth=5, n_estimators=200;, score=(train=-0.000, test=-8977.383) total time=   0.7s
# [CV 1/10] END learning_rate=1, max_depth=5, n_estimators=300;, score=(train=-0.000, test=-6975.027) total time=   0.8s
# [CV 2/10] END learning_rate=1, max_depth=5, n_estimators=300;, score=(train=-0.000, test=-5821.214) total time=   0.7s
# [CV 3/10] END learning_rate=1, max_depth=5, n_estimators=300;, score=(train=-0.000, test=-15422.678) total time=   0.7s
# [CV 4/10] END learning_rate=1, max_depth=5, n_estimators=300;, score=(train=-0.000, test=-11002.354) total time=   0.7s
# [CV 5/10] END learning_rate=1, max_depth=5, n_estimators=300;, score=(train=-0.000, test=-2532.866) total time=   0.6s
# [CV 6/10] END learning_rate=1, max_depth=5, n_estimators=300;, score=(train=-0.000, test=-3568.369) total time=   0.7s
# [CV 7/10] END learning_rate=1, max_depth=5, n_estimators=300;, score=(train=-0.000, test=-5083.351) total time=   0.7s
# [CV 8/10] END learning_rate=1, max_depth=5, n_estimators=300;, score=(train=-0.000, test=-4663.229) total time=   0.8s
# [CV 9/10] END learning_rate=1, max_depth=5, n_estimators=300;, score=(train=-0.000, test=-12268.595) total time=   1.1s
# [CV 10/10] END learning_rate=1, max_depth=5, n_estimators=300;, score=(train=-0.000, test=-11981.941) total time=   0.9s
# [CV 1/10] END learning_rate=1, max_depth=10, n_estimators=100;, score=(train=-0.000, test=-5435.857) total time=   0.1s
# [CV 2/10] END learning_rate=1, max_depth=10, n_estimators=100;, score=(train=-0.000, test=-11692.040) total time=   0.1s
# [CV 3/10] END learning_rate=1, max_depth=10, n_estimators=100;, score=(train=-0.000, test=-17980.571) total time=   0.1s
# [CV 4/10] END learning_rate=1, max_depth=10, n_estimators=100;, score=(train=-0.000, test=-7701.857) total time=   0.1s
# [CV 5/10] END learning_rate=1, max_depth=10, n_estimators=100;, score=(train=-0.000, test=-1626.286) total time=   0.1s
# [CV 6/10] END learning_rate=1, max_depth=10, n_estimators=100;, score=(train=-0.000, test=-4768.786) total time=   0.1s
# [CV 7/10] END learning_rate=1, max_depth=10, n_estimators=100;, score=(train=-0.000, test=-5917.214) total time=   0.1s
# [CV 8/10] END learning_rate=1, max_depth=10, n_estimators=100;, score=(train=-0.000, test=-4387.846) total time=   0.1s
# [CV 9/10] END learning_rate=1, max_depth=10, n_estimators=100;, score=(train=-0.000, test=-11826.154) total time=   0.1s
# [CV 10/10] END learning_rate=1, max_depth=10, n_estimators=100;, score=(train=-0.000, test=-11208.308) total time=   0.1s
# [CV 1/10] END learning_rate=1, max_depth=10, n_estimators=200;, score=(train=-0.000, test=-5095.571) total time=   0.1s
# [CV 2/10] END learning_rate=1, max_depth=10, n_estimators=200;, score=(train=-0.000, test=-9745.423) total time=   0.2s
# [CV 3/10] END learning_rate=1, max_depth=10, n_estimators=200;, score=(train=-0.000, test=-18023.786) total time=   0.1s
# [CV 4/10] END learning_rate=1, max_depth=10, n_estimators=200;, score=(train=-0.000, test=-8046.000) total time=   0.1s
# [CV 5/10] END learning_rate=1, max_depth=10, n_estimators=200;, score=(train=-0.000, test=-1980.000) total time=   0.1s
# [CV 6/10] END learning_rate=1, max_depth=10, n_estimators=200;, score=(train=-0.000, test=-3083.857) total time=   0.1s
# [CV 7/10] END learning_rate=1, max_depth=10, n_estimators=200;, score=(train=-0.000, test=-5604.357) total time=   0.1s
# [CV 8/10] END learning_rate=1, max_depth=10, n_estimators=200;, score=(train=-0.000, test=-5238.154) total time=   0.1s
# [CV 9/10] END learning_rate=1, max_depth=10, n_estimators=200;, score=(train=-0.000, test=-12812.462) total time=   0.1s
# [CV 10/10] END learning_rate=1, max_depth=10, n_estimators=200;, score=(train=-0.000, test=-11844.846) total time=   0.1s
# [CV 1/10] END learning_rate=1, max_depth=10, n_estimators=300;, score=(train=-0.000, test=-4908.786) total time=   0.1s
# [CV 2/10] END learning_rate=1, max_depth=10, n_estimators=300;, score=(train=-0.000, test=-11592.940) total time=   0.2s
# [CV 3/10] END learning_rate=1, max_depth=10, n_estimators=300;, score=(train=-0.000, test=-13744.071) total time=   0.1s
# [CV 4/10] END learning_rate=1, max_depth=10, n_estimators=300;, score=(train=-0.000, test=-3429.500) total time=   0.1s
# [CV 5/10] END learning_rate=1, max_depth=10, n_estimators=300;, score=(train=-0.000, test=-1583.071) total time=   0.1s
# [CV 6/10] END learning_rate=1, max_depth=10, n_estimators=300;, score=(train=-0.000, test=-3083.286) total time=   0.2s
# [CV 7/10] END learning_rate=1, max_depth=10, n_estimators=300;, score=(train=-0.000, test=-2611.429) total time=   0.2s
# [CV 8/10] END learning_rate=1, max_depth=10, n_estimators=300;, score=(train=-0.000, test=-6635.462) total time=   0.2s
# [CV 9/10] END learning_rate=1, max_depth=10, n_estimators=300;, score=(train=-0.000, test=-11581.769) total time=   0.1s
# [CV 10/10] END learning_rate=1, max_depth=10, n_estimators=300;, score=(train=-0.000, test=-7847.000) total time=   0.1s
# Model: GradientBoostingRegressor
# Normalization: MinMaxScaler
# Best Parameters: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 300}
# RMSE: 48.06844765092135
# R²: 0.761374670338168
# MAPE: 0.31064645351159936
# MAE: 36.28071995205142
#
# Model: GradientBoostingRegressor
# Normalization: StandardScaler
# Best Parameters: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}
# RMSE: 51.21905728725963
# R²: 0.7290684953210536
# MAPE: 0.3460142897979505
# MAE: 39.49790176830677
#
# Model: GradientBoostingRegressor
# Normalization: RobustScaler
# Best Parameters: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 300}
# RMSE: 49.82614056540213
# R²: 0.7436042363885038
# MAPE: 0.3129057330970533
# MAE: 37.83813657941661

# %% [markdown]
# # esemble

# %% [markdown]
# ## sem normalizar

# %%
X = data.drop('mg/dL', axis=1)
y = data['mg/dL']

# Dividir os dados em conjuntos de treinamento e teste
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)

# Definir os hiperparâmetros para cada modelo

rf_params = {
    'n_estimators': [100, 200, 300],
    'max_depth': [None, 5, 10],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

gb_params = {
    'n_estimators': [100, 200, 300],
    'learning_rate': [0.01, 0.1, 1],
    'max_depth': [3, 5, 10]
}


# Definir a lista de modelos com seus respectivos hiperparâmetros
models = [
    (RandomForestRegressor(), rf_params),
    (GradientBoostingRegressor(), gb_params),
]

# Lista para armazenar os resultados
results = []

# Iterar sobre os modelos
for model, params in models:
    # Criar o objeto GridSearchCV
    grid_search = GridSearchCV(estimator=model, param_grid=params, cv=10, verbose=5,
                               return_train_score=True, scoring='neg_mean_squared_error')

    # Realizar o grid search com cross-validation
    grid_search.fit(X_train, y_train)

    # Obter o melhor modelo encontrado
    best_model = grid_search.best_estimator_

    # Fazer previsões com o melhor modelo
    y_pred = best_model.predict(X_test)

    # Calcular as métricas de erro
    rmse = mean_squared_error(y_test, y_pred, squared=False)
    r2 = r2_score(y_test, y_pred)

    # Armazenar os resultados
    results.append({'Model': model.__class__.__name__,
                    'Best Parameters': grid_search.best_params_,
                    'RMSE': rmse,
                    'R²': r2})

# Obter os melhores parâmetros para RandomForestRegressor e GradientBoostingRegressor
best_rf_params = None
best_gb_params = None
best_rmse = float('inf')
for result in results:
    if result['Model'] == 'RandomForestRegressor' and result['RMSE'] < best_rmse:
        best_rf_params = result['Best Parameters']
        best_rmse = result['RMSE']
    elif result['Model'] == 'GradientBoostingRegressor' and result['RMSE'] < best_rmse:
        best_gb_params = result['Best Parameters']
        best_rmse = result['RMSE']


# Criar o modelo VotingRegressor com RandomForestRegressor e GradientBoostingRegressor usando os melhores parâmetros
voting_model = VotingRegressor([
    ('random_forest', RandomForestRegressor(**best_rf_params)),
    ('gradient_boosting', GradientBoostingRegressor(**best_gb_params))

])

# Lista para armazenar os resultados do VotingRegressor
voting_results = []

# Treinar e testar o modelo VotingRegressor
voting_model.fit(X_train, y_train)
y_pred = voting_model.predict(X_test)

# Calcular as métricas de erro para o VotingRegressor
voting_rmse = mean_squared_error(y_test, y_pred, squared=False)
voting_r2 = r2_score(y_test, y_pred)

# Armazenar os resultados do VotingRegressor
voting_results.append({'Model': 'VotingRegressor',
                       'Best Parameters': None,
                       'RMSE': voting_rmse,
                       'R²': voting_r2})

# Adicionar os resultados do VotingRegressor aos resultados gerais
results.extend(voting_results)

# Imprimir os resultados
for result in results:
    print('Model:', result['Model'])
    print('Best Parameters:', result['Best Parameters'])
    print('RMSE:', result['RMSE'])
    print('R²:', result['R²'])
    print()
# Out:
# Fitting 10 folds for each of 81 candidates, totalling 810 fits
# [CV 1/10] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=(train=-703.393, test=-3848.645) total time=   1.7s
# [CV 2/10] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=(train=-704.587, test=-4719.927) total time=   1.3s
# [CV 3/10] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=(train=-721.667, test=-6814.574) total time=   1.1s
# [CV 4/10] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=(train=-662.267, test=-3982.859) total time=   1.1s
# [CV 5/10] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=(train=-740.289, test=-3251.151) total time=   1.4s
# [CV 6/10] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=(train=-743.870, test=-2568.998) total time=   1.3s
# [CV 7/10] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=(train=-772.012, test=-4404.965) total time=   1.2s
# [CV 8/10] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=(train=-737.314, test=-3531.970) total time=   1.1s
# [CV 9/10] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=(train=-589.496, test=-7443.944) total time=   1.1s
# [CV 10/10] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=(train=-677.344, test=-4720.668) total time=   1.4s
# [CV 1/10] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=(train=-659.460, test=-4263.195) total time=   3.3s
# [CV 2/10] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=(train=-722.363, test=-5158.565) total time=   2.2s
# [CV 3/10] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=(train=-647.848, test=-6754.625) total time=   2.2s
# [CV 4/10] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=(train=-635.203, test=-4185.634) total time=   2.2s
# [CV 5/10] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=(train=


# Dividir os dados em conjuntos de treinamento e teste
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)

# Definir os hiperparâmetros para cada modelo

rf_params = {
    'n_estimators': [100, 200, 300],
    'max_depth': [None, 5, 10],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}
gb_params = {
    'n_estimators': [100, 200, 300],
    'learning_rate': [0.01, 0.1, 1],
    'max_depth': [3, 5, 10]
}

# Definir a lista de modelos com seus respectivos hiperparâmetros
models = [

    (RandomForestRegressor(), rf_params),
    (GradientBoostingRegressor(), gb_params),
]

# Definir a lista de normalizações
scalers = [
    ('MinMaxScaler', MinMaxScaler()),
    ('StandardScaler', StandardScaler()),
    ('RobustScaler', RobustScaler())
]

# Lista para armazenar os resultados
results = []

# Iterar sobre as normalizações
for scaler_name, scaler in scalers:
    # Normalizar os dados
    X_train_scaled = scaler.fit_transform(X_train)
    X_test_scaled = scaler.transform(X_test)

    # Iterar sobre os modelos
    for model, params in models:
        # Criar o objeto GridSearchCV
        grid_search = GridSearchCV(estimator=model, param_grid=params, cv=10, verbose=5,
                                   return_train_score=True, scoring='neg_mean_squared_error')

        # Realizar o grid search com cross-validation nos dados de treinamento
        grid_search.fit(X_train_scaled, y_train)

        # Obter o melhor modelo encontrado
        best_model = grid_search.best_estimator_

        # Fazer previsões com o melhor modelo nos dados de teste
        y_pred = best_model.predict(X_test_scaled)

        # Calcular as métricas de erro
        rmse = mean_squared_error(y_test, y_pred, squared=False)
        r2 = r2_score(y_test, y_pred)
        mape = mean_absolute_percentage_error(y_test, y_pred)
        mae = mean_absolute_error(y_test, y_pred)

        # Armazenar os resultados
        results.append({'Model': model.__class__.__name__,
                        'Normalization': scaler_name,
                        'Best Parameters': grid_search.best_params_,
                        'RMSE': rmse,
                        'R²': r2,
                        'MAPE': mape,
                        'MAE': mae})

# Obter os melhores parâmetros para RandomForestRegressor e GradientBoostingRegressor
best_rf_params = None
best_gb_params = None

best_rmse = float('inf')
for result in results:
    if result['Model'] == 'RandomForestRegressor' and result['RMSE'] < best_rmse:
        best_rf_params = result['Best Parameters']
        best_rmse = result['RMSE']
    elif result['Model'] == 'GradientBoostingRegressor' and result['RMSE'] < best_rmse:
        best_gb_params = result['Best Parameters']
        best_rmse = result['RMSE']


# Criar o modelo VotingRegressor com RandomForestRegressor e GradientBoostingRegressor usando os melhores parâmetros
voting_model = VotingRegressor([
    ('random_forest', RandomForestRegressor(**best_rf_params)),
    ('gradient_boosting', GradientBoostingRegressor(**best_gb_params))

])

# Lista para armazenar os resultados do VotingRegressor
voting_results = []

# Iterar sobre as normalizações
for scaler_name, scaler in scalers:
    # Normalizar os dados
    X_train_scaled = scaler.fit_transform(X_train)
    X_test_scaled = scaler.transform(X_test)

    # Clonar o modelo VotingRegressor
    voting_model_cloned = clone(voting_model)

    # Treinar o modelo VotingRegressor nos dados de treinamento
    voting_model_cloned.fit(X_train_scaled, y_train)

    # Fazer previsões com o modelo VotingRegressor nos dados de teste
    y_pred = voting_model_cloned.predict(X_test_scaled)

    # Calcular as métricas de erro
    rmse = mean_squared_error(y_test, y_pred, squared=False)
    r2 = r2_score(y_test, y_pred)
    mape = mean_absolute_percentage_error(y_test, y_pred)
    mae = mean_absolute_error(y_test, y_pred)

    # Armazenar os resultados
    voting_results.append({'Model': 'VotingRegressor',
                           'Normalization': scaler_name,
                           'Best Parameters': None,
                           'RMSE': rmse,
                           'R²': r2,
                           'MAPE': mape,
                           'MAE': mae})

# Adicionar os resultados do VotingRegressor aos resultados gerais
results.extend(voting_results)

# Imprimir os resultados
for result in results:
    print('Model:', result['Model'])
    print('Normalization:', result['Normalization'])
    print('Best Parameters:', result['Best Parameters'])
    print('RMSE:', result['RMSE'])
    print('R²:', result['R²'])
    print('MAPE:', result['MAPE'])
    print('MAE:', result['MAE'])
    print()
